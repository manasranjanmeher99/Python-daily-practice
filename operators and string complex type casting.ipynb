# %%
complex(10)
# Out:
# (10+0j)

# %% [markdown]
# #other to comple Data type

# %%
complex(,20)
# Out:
#   Cell In[2], line 1
#     complex(,20)
#             ^
# SyntaxError: invalid syntax

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(2.3)
# Out:
# (2.3+0j)

# %%
complex(2.3,4.5)
# Out:
# (2.3+4.5j)

# %%
complex(2,2)
# Out:
# (2+2j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('10','20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 complex('10','20')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(10,'20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 complex(10,'20')
#
# TypeError: complex() second arg can't be a string

# %% [markdown]
# Other to String Data Type

# %%
str(5)
# Out:
# '5'

# %%
str(10+2j)
# Out:
# '(10+2j)'

# %%
str(True)
# Out:
# 'True'

# %%
str(2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 str(2,3)
#
# TypeError: str() argument 'encoding' must be str, not int

# %%
str("True")
# Out:
# 'True'

# %%
str(2.3)
# Out:
# '2.3'

# %%
str('manas','ranjan')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 str('manas','ranjan')
#
# TypeError: decoding str is not supported

# %%
x=7
id(x)
# Out:
# 140718011819112

# %%
y=-7
id(y)
# Out:
# 2492866308496

# %% [markdown]
# Operators

# %%
x1,y1=40,5
x1/y1
# Out:
# 8.0

# %%
x1,y1=40,5
x1//y1
# Out:
# 8

# %%
a=6
b=7
a>5 and b<7
# Out:
# False

# %%
a=6
b=7
a>5 and b>7
# Out:
# False

# %%
a=5
b=7
not(a>5 and b<8)
# Out:
# True

# %%
a=6
b=7
a>5 or b<7
# Out:
# True

# %%
a=6
b=7
not(a>5 or b<7)
# Out:
# False

# %%
not(False)
# Out:
# True

# %%
a=6
b=7
a>5 or b<7 and b>5
# Out:
# True

# %%
a=6
b=7
b<7 and b>5
# Out:
# False

# %%
a=6
b=7
a>5 and b<7 and b>5
# Out:
# False

# %%
a=6
b=7
a>5 and b<7 or b>5
# Out:
# True

# %%
a=6
b=7
a>5 and b<7
# Out:
# False

# %%
var=2
print(2==2.0)
# Out:
# True
