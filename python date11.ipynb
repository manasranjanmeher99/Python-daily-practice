# %% [markdown]
# Data Type

# %%
c= 10+20j
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
type(c)
# Out:
# complex

# %%
s= "Hello World
buhudgg
hidhu"
s
# Out:
#   Cell In[6], line 1
#     s= "Hello World
#        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s=''' Hello World
buhudgg
hidhu'''
s
# Out:
# ' Hello World\nbuhudgg\nhidhu'

# %% [markdown]
# Celling

# %%
s1= "Hello World"
s1[:]
# Out:
# 'Hello World'

# %%
type(s1)
# Out:
# str

# %%
print(s1[0:5])
print(s1[5:11])
print(s1[0:11:2])
# Out:
# Hello
#  World
# HloWrd

# %%
print(s1[-1])
# Out:
# d

# %%
print(s1[:])
print(s1[1:8])
print(s1[1:8:3])
# Out:
# Hello World
# ello Wo
# eoo

# %%
s2= "Hello World"
len(s2)
# Out:
# 11

# %%
x=5
y=5
print(id(x))
print(id(y))
# Out:
# 140717991765032
# 140717991765032

# %%
x=5
y=10
print(id(x))
print(id(y))
# Out:
# 140717991765032
# 140717991765192

# %%
print(s1[0:-1])
print(s1[-10:-1])
# Out:
# Hello Worl
# ello Worl

# %%
print(s1[:-1])
print(s1[0:-1:2])
# Out:
# Hello Worl
# HloWr

# %%
c1= 10+20j
c2= 30+40j
print(c1+c2)
# Out:
# (40+60j)

# %%
c3= c1-c2
print(c3)
# Out:
# (-20-20j)

# %%
c1= 10+20j
c4= c1*2
print(c4)
# Out:
# (20+40j)

# %%
c1= 10+20j
c2= 30+40j
c1/c2
# Out:
# (0.44+0.08j)

# %%
c5= 20j
print(c5.real)
print(c5.imag)
# Out:
# 0.0
# 20.0

# %%
c6= 10+20i
c6
# Out:
#   Cell In[44], line 1
#     c6= 10+20i
#             ^
# SyntaxError: invalid decimal literal

# %%
e1= 10e0
e2= 10e0-1
e3= 10e1
e4= 10e2
e5= 10e3
e6=10e7
e7= 20e0
print(e1)
print(e2)
print(e3)
print(e4)
print(e5)
print(e6)
print(e7)
# Out:
# 10.0
# 9.0
# 100.0
# 1000.0
# 10000.0
# 100000000.0
# 20.0

# %%
s3="welcometeam"
s3[0:8:-1]
# Out:
# ''

# %%
s3="welcometeam"
s3[-1:-12:-1]
# Out:
# 'maetemoclew'

# %%
s3="welcometeam"
s3[-2:-8:-2]
# Out:
# 'atm'

# %%
a1 = "abcd"
a1[3:1:-1]
# Out:
# 'dc'
