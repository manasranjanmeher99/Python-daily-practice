# %%
bin(21)
# Out:
# '0b10101'

# %%
int(0b10101)
# Out:
# 21

# %%
hex(25)
# Out:
# '0x19'

# %%
int(0x19)
# Out:
# 25

# %%
bin(78)
# Out:
# '0b1001110'

# %%
int(0b1001110)
# Out:
# 78

# %% [markdown]
# Octal number system

# %%
oct(21)
# Out:
# '0o25'

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
oct(8)
# Out:
# '0o10'

# %%
int(0o10)
# Out:
# 8

# %%
int(0o1)
# Out:
# 1

# %%
int(0o101)
# Out:
# 65

# %%
int(0o64)
# Out:
# 52

# %%
oct(52)
# Out:
# '0o64'

# %%
oct(65)
# Out:
# '0o101'

# %% [markdown]
# HexaDecimal

# %%
hex(25)
# Out:
# '0x19'

# %%
int(0x19)
# Out:
# 25

# %%
hex(18)
# Out:
# '0x12'

# %%
hex(30)
# Out:
# '0x1e'

# %%
int(0x1ab)
# Out:
# 427

# %%
int(0x1a)
# Out:
# 26

# %%
hex(26)
# Out:
# '0x1a'

# %%
hex(27)
# Out:
# '0x1b'

# %%
hex(43)
# Out:
# '0x2b'

# %% [markdown]
# Bitwise Operator

# %%
~5  #complement
# Out:
# -6

# %%
~23 #complement
# Out:
# -24

# %%
12 & 13 #and&
# Out:
# 12

# %%
12 & 20
# Out:
# 4

# %%
12 & 30
# Out:
# 12

# %% [markdown]
# #bitwise or |

# %%
12 | 13
# Out:
# 13

# %%
34|56
# Out:
# 58

# %%
12|13
# Out:
# 13

# %% [markdown]
# Bitwise xor

# %%
25 ^ 30
# Out:
# 7

# %%
12 ^ 13
# Out:
# 1

# %%
23^26
# Out:
# 13

# %% [markdown]
# Shifting

# %%
12<<1  #left shift
# Out:
# 24

# %%
12 << 2   #left shift
# Out:
# 48

# %%
12 << 3   #left shift
# Out:
# 96

# %%
12 << 4   #left shift
# Out:
# 192

# %%
12 >> 1   # right shift
# Out:
# 6

# %%
12 >> 2    # right shift
# Out:
# 3

# %%
12 >> 3    # right shift
# Out:
# 1

# %%
12 >> 4    # right shift
# Out:
# 0

# %%
13 >> 3     # right shift
# Out:
# 1

# %%
25 >> 1     # right shift
# Out:
# 12

# %%
25 >> 2   # right shift
# Out:
# 6

# %%
25 >> 3   # right shift
# Out:
# 3

# %%
name1= "alice"
name2="bob"
print(name1>name2)
# Out:
# False

# %%
name1= "alice"
name2="bob"
print(name1 < name2)
# Out:
# True

# %%
n1="A"
n2="a"
print(n1 <= n2)
# Out:
# True

# %%
n1="A"
n2="a"
print(n1 >= n2)
# Out:
# False

# %%
n1="A"
n2="a"
print(n1 < n2)
# Out:
# True

# %% [markdown]
# Print format method

# %%
n1= 20
n2 = 30
add= n1+n2
print("The addition of {} and {} is = {}".format(n1,n2,add))
# Out:
# The addition of 20 and 30 is = 50

# %%
n1= 20
n2 = 30
add= n1+n2
print(f"The addition of {n1} and {n2} is = {add}")
# Out:
# The addition of 20 and 30 is = 50

# %% [markdown]
# Hexadecimal to Other number System

# %%
oct(0x1ab)    #hexa-decimal to octal
# Out:
# '0o653'

# %%
oct(0x5ef)  #hexa-decimal to octal
# Out:
# '0o2757'

# %%
bin(0x1ab)    #hexa-decimal to binary
# Out:
# '0b110101011'

# %%
bin(0x5ef)    #hexa-decimal to binary
# Out:
# '0b10111101111'

# %%
int(0x1ab)    #hexa-decimal to decimal
# Out:
# 427

# %%
int(0x5ef)    #hexa-decimal to decimal
# Out:
# 1519

# %% [markdown]
# Octal to other number system

# %%
bin(0o23)    #octal to binary
# Out:
# '0b10011'

# %%
bin(0o54)    #octal to binary
# Out:
# '0b101100'

# %%
int(0o23)    #octal to decimal
# Out:
# 19

# %%
int(0o54)    #octal to decimal
# Out:
# 44

# %%
hex(0o23)    #octal to hexa-decimal
# Out:
# '0x13'

# %%
hex(0o54)  #octal to hexa-decimal
# Out:
# '0x2c'

# %% [markdown]
# decimal to other number system

# %%
bin(23)      #decimal to binary
# Out:
# '0b10111'

# %%
bin(54)      #decimal to binary
# Out:
# '0b110110'

# %%
oct(23)       #decimal to octal
# Out:
# '0o27'

# %%
oct(54)       #decimal to octal
# Out:
# '0o66'

# %%
hex(23)    #decimal to hexa-decimal
# Out:
# '0x17'

# %%
hex(54)   #binary to hexa-decimal
# Out:
# '0x36'

# %%
print("hello....")
print("i am manas ranjan meher")
# Out:
# hello....
# i am manas ranjan meher

# %%
print("hello....", end="")
print("i am manas ranjan meher")
# Out:
# hello....i am manas ranjan meher

# %%
print("hell0....", " i am manas..."," how can i help you?",sep="---->")
# Out:
# hell0....----> i am manas...----> how can i help you?
