# %%
x=True
type(x)
# Out:
# bool

# %%
x=584.9
type(x)
# Out:
# float

# %%
x=5
id(x)
# Out:
# 140717991765032

# %%
x=5/2
x
# Out:
# 2.5

# %% [markdown]
# Datatype

# %%
c=10+20j
c.real
# Out:
# 10.0

# %%
x=6
y=x+1
y
# Out:
# 7
