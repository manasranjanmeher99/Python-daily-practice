# %%
l=[]
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
l.append(10)
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l.append(10)
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1=[10,2.3,True,2+3j,'nit',[1,2,3]]
l1
# Out:
# [10, 2.3, True, (2+3j), 'nit', [1, 2, 3]]

# %%
len(l1)
# Out:
# 6

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.3, True, (2+3j), 'nit', [1, 2, 3]]

# %%
print(id(l))
print(id(l1))
# Out:
# 2203008622720
# 2203014947968

# %%
l2=l1.copy()
l2
# Out:
# [10, 2.3, True, (2+3j), 'nit', [1, 2, 3]]

# %%
l2.count(10)
# Out:
# 1

# %%
l2.clear()

# %%
l2
# Out:
# []

# %%
len(l2)
# Out:
# 0

# %%
del l2

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l.count(l0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 l.count(l0)
#
# NameError: name 'l0' is not defined

# %%
l.count(10)
# Out:
# 2

# %%
l.count(20)
# Out:
# 1

# %%
l.count(100)
# Out:
# 0

# %%
a=[1,2,3]
b=[4,5,6]
a.extend(b)
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
b
# Out:
# [4, 5, 6]

# %%
l2=[]
l2
# Out:
# []

# %%
l2.extend(l,l1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 l2.extend(l,l1)
#
# TypeError: list.extend() takes exactly one argument (2 given)

# %%
l2.extend(l)

# %%
l2
# Out:
# [10, 2.3, True, (2+3j), 'nit', [1, 2, 3], 10, 20, 30, 40, 50, 10]

# %%
l2
# Out:
# [10, 2.3, True, (2+3j), 'nit', [1, 2, 3], 10, 20, 30, 40, 50, 10]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l2.index(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 l2.index(2)
#
# ValueError: 2 is not in list

# %%
l2.index(2.3)
# Out:
# 1

# %%
l[0]
# Out:
# 10

# %%
l[0]=100

# %%
l
# Out:
# [100, 20, 30, 40, 50, 10]

# %%
l[-2]=500

# %%
l
# Out:
# [100, 20, 30, 40, 500, 10]

# %%
l.index(100)
# Out:
# 0

# %%
l2.index(10)
# Out:
# 0

# %%
l2.index[10]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 l2.index[10]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
l2
# Out:
# [10, 2.3, True, (2+3j), 'nit', [1, 2, 3], 10, 20, 30, 40, 50, 10]

# %%
l2.count(10)
# Out:
# 3

# %%
l.insert(2,25)

# %%
l
# Out:
# [100, 20, 25, 30, 40, 500, 10]

# %%
l.pop()
# Out:
# 10

# %%
l2
# Out:
# [10, 2.3, True, (2+3j), 'nit', [1, 2, 3], 10, 20, 30, 40, 50, 10]

# %%
l1
# Out:
# [10, 2.3, True, (2+3j), 'nit', [1, 2, 3]]

# %%
l1.pop()
# Out:
# [1, 2, 3]

# %%
l1
# Out:
# [10, 2.3, True, (2+3j), 'nit']

# %%
l1.pop()
# Out:
# 'nit'

# %%
l1
# Out:
# [10, 2.3, True, (2+3j)]

# %%
l2.pop(2)
# Out:
# True

# %%
l2
# Out:
# [10, 2.3, (2+3j), 'nit', [1, 2, 3], 10, 20, 30, 40, 50, 10]

# %%
l2.pop(2)
# Out:
# (2+3j)

# %%
l2
# Out:
# [10, 2.3, 'nit', [1, 2, 3], 10, 20, 30, 40, 50, 10]

# %%
l2.remove(10)

# %%
l2
# Out:
# [2.3, 'nit', [1, 2, 3], 10, 20, 30, 40, 50, 10]

# %%
l2.pop(-1)
# Out:
# 10

# %%
l2
# Out:
# [2.3, 'nit', [1, 2, 3], 10, 20, 30, 40, 50]

# %%
l
# Out:
# [100, 20, 25, 30, 40, 500]

# %%
l.reverse()

# %%
l
# Out:
# [500, 40, 30, 25, 20, 100]

# %%
l.sort()

# %%
l
# Out:
# [20, 25, 30, 40, 100, 500]

# %%
l.append(10)

# %%
l
# Out:
# [20, 25, 30, 40, 100, 500, 10]

# %%
l.sort()   #assending order

# %%
l
# Out:
# [10, 20, 25, 30, 40, 100, 500]

# %%
l.sort(reverse=True)

# %%
l.sort(reverse=True)

# %%
l
# Out:
# [500, 100, 40, 30, 25, 20, 10]

# %%
l
# Out:
# [500, 100, 40, 30, 25, 20, 10]

# %%
l1
# Out:
# [10, 2.3, True, (2+3j)]

# %%
l2
# Out:
# [2.3, 'nit', [1, 2, 3], 10, 20, 30, 40, 50]

# %%
l2.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 l2.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
l3=[10,20,[2,3],3]

# %%
l3
# Out:
# [10, 20, [2, 3], 3]

# %%
l3.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 l3.sort()
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
20 in l3
# Out:
# True

# %%
30 in l3
# Out:
# False

# %%
for i in l:     #for loop
    print(i)
# Out:
# 500
# 100
# 40
# 30
# 25
# 20
# 10
