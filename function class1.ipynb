# %%
def greet(): # greet() without argument 
    print('good morning')

# %%
def greet(): # greet() without argument 
    print('good morning everyone')
greet()
# Out:
# good morning everyone

# %%
def greet(): # greet() without argument 
    print('good morning everyone')
greet()

def greet(): # greet() without argument 
    print('good morning everyone')
greet()
# Out:
# good morning everyone
# good morning everyone

# %%
def greet(): # greet() without argument 
    print('good morning everyone')
    print('good bye everyone')

greet()
greet()
greet()
# Out:
# good morning everyone
# good bye everyone
# good morning everyone
# good bye everyone
# good morning everyone
# good bye everyone

# %%
def add(x,y): # x,y is called formal argument 
    c=x+y
    print(c)  
add(5,6) # 5 ^ is called actual argument
# Out:
# 11

# %%
def add(x, y):  # x,y is called formal argument
    c=x+y
    print(c)  
add(5)         # 5 only one argument is given but two are expected, so it will give error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       2     c=x+y
#       3     print(c)
# ----> 4 add(5)         # 5 only one argument is given but two are expected, so it will give error
#
# TypeError: add() missing 1 required positional argument: 'y'

# %%
def add(x):  # x is called formal argument
    c=x+y
    print(c)  
add(5, 6)   # 5 and 6 are actual arguments but only one formal argument is given, so it will give error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2     c=x+y
#       3     print(c)
# ----> 4 add(5, 6)   # 5 and 6 are actual arguments but only one formal argument is given, so it will give error
#
# TypeError: add() takes 1 positional argument but 2 were given

# %%
def add(x,y): 
    c=x+y 
    print(c)  
add(5, 6)
# Out:
# 11

# %%
def add(x,y): 
    c=x+y 
    return c  
add(5, 6)
# Out:
# 11

# %%
def add(x,y): 
    c=x+y 
    print(c)  

result = add(5, 6)
print(result)
print(type(result))    # NoneType means it is not returning anything, it is just printing the value of c but not returning it, so it will give None as output when we try to print the result.
# Out:
# 11
# None
# <class 'NoneType'>

# %%
def add(x,y): 
    c=x+y 
    return c  
result1 = add(5, 6)
print(result1)
print(type(result1)) # int means it is returning an integer value, it is returning the value of c which is 11
# Out:
# 11
# <class 'int'>

# %%
def greet(): # greet() without argument 
    print('good morning everyone')
greet()

def add(x,y): 
    c=x+y 
    return c  
add(5,6)
# Out:
# good morning everyone
# 11

# %%
def greet(): # greet() without argument 
    print('good morning everyone')
    #return 'good morning'
    
def add(x,y): 
    c=x+y 
    return c  

def sub(x,y):
    d = x-y
    return d

r  = greet()   
r1 = add(5,6)
r2 = sub(6,5)

print(r)
print(r1)
print(r2)
# Out:
# good morning everyone
# None
# 11
# 1

# %%
def add_sub(x,y): # what if i want to return 2 values add_sub & i want to return 2 values & function can accept multiple value 
    c= x+y
    d= x-y
    return c, d 
    
result = add_sub(5,4)
print(result)

print(type(result))
# Out:
# (9, 1)
# <class 'tuple'>

# %%
def add_sub(x,y): # what if i want to return 2 values add_sub & i want to return 2 values & function can accept multiple value 
    c= x+y
    d= x-y
    
    return c, d 
    
r, r1 = add_sub(5,4)
print(r)
print(r1)

print(type(r))
print(type(r1))
# Out:
# 9
# 1
# <class 'int'>
# <class 'int'>

# %% [markdown]
# # positional argument

# %%
def person(name,age):
    print(name)
    print(age)
    
person('nit', 23)
# Out:
# nit
# 23

# %%
def person(name,age):
    print(name)
    print(age)
    
person('nit') # it will give error because one argument is missing, it is expecting 2 arguments but only one is given
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       2     print(name)
#       3     print(age)
# ----> 5 person('nit') # it will give error because one argument is missing, it is expecting 2 arguments but only one is given
#
# TypeError: person() missing 1 required positional argument: 'age'

# %% [markdown]
# # keyword argument

# %%
def person(name,age):
    print(name)
    print(age+1)
    
person(age = 23, name = 'nit')
# Out:
# nit
# 24

# %%
def person(name, age, age2):
    print(name)
    print(age)
    print(age2)
    
person(age=20,  name='nit', age2 = 30)
# Out:
# nit
# 20
# 30

# %% [markdown]
# # default argument

# %%
def person(name,age):
    print(name)
    print(age)
    
person('nit') # it will give error because one argument is missing, it is expecting 2 arguments but only one is given
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 5
#       2     print(name)
#       3     print(age)
# ----> 5 person('nit') # it will give error because one argument is missing, it is expecting 2 arguments but only one is given
#
# TypeError: person() missing 1 required positional argument: 'age'

# %%
def person(name, age=18):  # age is given default value 18
    print(name)
    print(age)
    
person('nit')
# Out:
# nit
# 18

# %% [markdown]
# # variable lenght argument

# %%
def sum(a, b):
    c = a+b
    print(c)
    
sum(5,6)
# Out:
# 11

# %%
def sum(a, b):
    c = a+b
    print(c)
    
sum(5,6,7,8) # it will give error because only 2 arguments are expected but 4 are given
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 5
#       2     c = a+b
#       3     print(c)
# ----> 5 sum(5,6,7,8) # it will give error because only 2 arguments are expected but 4 are given
#
# TypeError: sum() takes 2 positional arguments but 4 were given

# %%
def sum(a, *b): # 1st argument is fixed but for 2nd argument
    
    print(a)
    print(b)

sum(5,6,7,8)
# Out:
# 5
# (6, 7, 8)

# %%
def sum(a, *b): # 1st argument is fixed but for 2nd argument
    
    print(type(a))
    print(type(b))

sum(5,6,7,8)
# Out:
# <class 'int'>
# <class 'tuple'>

# %%
def sum(a, *b): # 1st argument is fixed & we fetch each value from the tuple & we can add them. 
    
    c = a   
    
    for i in b:
        c = c + i 
    print(c)
        
sum(5,6,7,8)
# Out:
# 26

# %%
def sum(a, *b): # 1st argument is fixed & we fetch each value from the tuple & we can add them. 
    c = a   
    
    for i in b:
        c = c + i 
    print(c)
        
sum(5,6,7,8,9,10,-1, 100, 2.3)
# Out:
# 146.3

# %%
def sum(a, *b): # 1st argument is fixed & we fetch each value from the tuple & we can add them. 
    c = 0   
    
    for i in b:
        c = c + i 
    print(c) 
        
sum(5,6,7,8)
# Out:
# 21

# %% [markdown]
# # kwargs ( kw + args)

# %%
def person():
    person('Alex', 36, 'John', 987767)
person()  # it will give error because person() is expecting 0 argument but 4 are given
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 3
#       1 def person():
#       2     person('Alex', 36, 'John', 987767)
# ----> 3 person()  # it will give error because person() is expecting 0 argument but 4 are given
#
# Cell In[45], line 2, in person()
#       1 def person():
# ----> 2     person('Alex', 36, 'John', 987767)
#
# TypeError: person() takes 0 positional arguments but 4 were given

# %%
def person(name, *data):
    print(name)
    print(data)

person('Alex', 36, 'John', 987)
# Out:
# Alex
# (36, 'John', 987)

# %%
def person(name,*data):
    print('name')
    print(data)

person('Alex', age = 36, city ='hyd', mob =987) # it will give error because we cannot use keyword argument with *data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 5
#       2     print('name')
#       3     print(data)
# ----> 5 person('Alex', age = 36, city ='hyd', mob =987) # it will give error because we cannot use keyword argument with *data
#
# TypeError: person() got an unexpected keyword argument 'age'

# %%
def person(name,**data):
    print('name')
    print(data)

person('Alex', age = 36, city ='hyd', mob =987)
# Out:
# name
# {'age': 36, 'city': 'hyd', 'mob': 987}

# %%
def person(name,**data):
    print('name')
    print(data)

person('ALEX', age = 36, home_place ='southcity', mob =987767, car = 'german')
# Out:
# name
# {'age': 36, 'home_place': 'southcity', 'mob': 987767, 'car': 'german'}
